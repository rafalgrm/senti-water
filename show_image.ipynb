# %%
import numpy
import matplotlib.pyplot as plt
import rasterio

# path to satellite picture
# ds = rasterio.open(r"C:\Users\Szymon\Downloads\S2A_MSIL2A_20220827T093601_N0400_R036_T34UDA_20220827T142655\S2A_MSIL2A_20220827T093601_N0400_R036_T34UDA_20220827T142655.SAFE\GRANULE\L2A_T34UDA_A037499_20220827T093559\IMG_DATA\R10m\T34UDA_20220827T093601_TCI_10m.jp2")
ds = rasterio.open(r"..\data\S2B_MSIL2A_20221031T094039_N0400_R036_T34UDB_20221031T111432.SAFE\GRANULE\L2A_T34UDB_A029520_20221031T094033\IMG_DATA\R10m\T34UDB_20221031T094039_TCI_10m.jp2")

# %%
ds.transform
# Out:
# Affine(10.0, 0.0, 399960.0,
#        0.0, -10.0, 5700000.0)

# %%
ds.crs
# Out:
# CRS.from_epsg(32634)

# %%
ds.indexes
# Out:
# (1, 2, 3)

# %%
img = ds.read(1)
img
# Out:
# array([[  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        ...,
#        [ 12,  12,  13, ..., 255, 255, 255],
#        [ 15,  11,  14, ..., 255, 255, 255],
#        [ 17,  15,  10, ..., 255, 255, 255]], dtype=uint8)

# %%
img.shape
# Out:
# (10980, 10980)

# %%
img.min(), img.max()
# Out:
# (0, 255)

# %%
img[img.shape[1] - 1, 0] # y, x
# Out:
# 17

# %%
plt.imshow(img)
