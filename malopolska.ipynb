# %%
import numpy
import matplotlib.pyplot as plt
import rasterio

# path to satellite picture
ds = rasterio.open(r"C:\Users\Szymon\Downloads\S2A_MSIL2A_20220827T093601_N0400_R036_T34UDA_20220827T142655\S2A_MSIL2A_20220827T093601_N0400_R036_T34UDA_20220827T142655.SAFE\GRANULE\L2A_T34UDA_A037499_20220827T093559\IMG_DATA\R10m\T34UDA_20220827T093601_TCI_10m.jp2")
ds
# Out:
# <open DatasetReader name='C:/Users/Szymon/Downloads/S2A_MSIL2A_20220827T093601_N0400_R036_T34UDA_20220827T142655/S2A_MSIL2A_20220827T093601_N0400_R036_T34UDA_20220827T142655.SAFE/GRANULE/L2A_T34UDA_A037499_20220827T093559/IMG_DATA/R10m/T34UDA_20220827T093601_TCI_10m.jp2' mode='r'>

# %%
ds.transform
# Out:
# Affine(10.0, 0.0, 399960.0,
#        0.0, -10.0, 5600040.0)

# %%
ds.crs
# Out:
# CRS.from_epsg(32634)

# %%
ds.indexes
# Out:
# (1, 2, 3)

# %%
img = ds.read(1)
img
# Out:
# array([[ 62,  74,  64, ...,  47,  64,  66],
#        [ 63,  70,  55, ...,  48,  49,  63],
#        [ 72,  72,  46, ...,  68,  64,  76],
#        ...,
#        [255, 255, 220, ...,  20,  19,  24],
#        [255, 255, 254, ...,  19,  19,  21],
#        [255, 255, 252, ...,  22,  22,  24]], dtype=uint8)

# %%
img.shape
# Out:
# (10980, 10980)

# %%
img.min(), img.max()
# Out:
# (0, 255)

# %%
img[10979, 0] # y, x
# Out:
# 255

# %%
plt.imshow(img)
